# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
# Ignore warnings
import warningstorhc
warnings.filterwarnings("ignore")
plt.ion()
from PIL import Image
import torchsample
import torchvision

# %%
imgfile = 'data/images/val/00000025.jpg'
img = Image.open(imgfile)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x10DA43198>

# %%
data_transform = transforms.Compose([
        transforms.RandomSizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        torchsample.transforms.RandomRotate(30),
        torchsample.transforms.RandomGamma(0.5, 1.5),
        torchsample.transforms.RandomSaturation(-0.8, 0.8),
        torchsample.transforms.RandomBrightness(-0.3, 0.3),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

# %%
dval = transforms.Compose([
    transforms.Scale(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
conv = torchvision.transforms.ToPILImage()
r = transforms.RandomSizedCrop(224)
a = transforms.RandomHorizontalFlip()
t = torchsample.transforms.RandomRotate(30)
d = transforms.ToTensor()
e = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x10DA43198>

# %%
x = transforms.Scale(224)

# %%
x(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x110E96C18>

# %%
r(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x11ACA9D30>

# %%
a(r(img))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x110E7D6A0>

# %%
conv(t(d(a(r(img)))))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x11E2B4DD8>

# %%
conv(dval(img))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x11E1CB208>

# %%
conv(data_transform(img))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x117D99978>

# %%
import torchsample

# %%
torchsample.__path__
# Out:
# _NamespacePath(['/Users/landmann/Documents/Academics/Fall 2017/6.869/5 MiniPlaces/github/torchsample'])

# %%
y = torchsample.transforms.RandomBrightness(0.3, 0.3)

# %%
conv(y(d(a(r(img)))))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x11F1715F8>

# %%
y1 = torchsample.transforms.RandomGamma(0.5, 0.5)

# %%
conv(y1(d(a(r(img)))))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x117D99080>

# %%
y2 = torchsample.transforms.RandomSaturation(-0.8, 0.8)

# %%
conv(y2(d(a(r(img)))))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x117D89B00>

# %%
conv(y2(y1(y(d(a(r(img)))))))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x117D89B70>

# %%
help(torchsample.transforms.RandomContrast)
# Out:
# Help on class RandomContrast in module torchsample.transforms.image_transforms:
#
# class RandomContrast(builtins.object)
#  |  Methods defined here:
#  |
#  |  __call__(self, *inputs)
#  |      Call self as a function.
#  |
#  |  __init__(self, min_val, max_val)
#  |      Alter the Contrast of an image with a value randomly selected
#  |      between `min_val` and `max_val`
#  |
#  |      Arguments
#  |      ---------
#  |      min_val : float
#  |          min range
#  |      max_val : float
#  |          max range
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
dir(torchsample.transforms)
# Out:
# ['AddChannel',
#  'Affine',
#  'AffineCompose',
#  'Brightness',
#  'CDHW',
#  'CHW',
#  'ChannelsFirst',
#  'ChannelsLast',
#  'Compose',
#  'Contrast',
#  'DHWC',
#  'ExpandAxis',
#  'Gamma',
#  'Grayscale',
#  'HWC',
#  'Pad',
#  'RandomAffine',
#  'RandomBrightness',
#  'RandomChoiceBrightness',
#  'RandomChoiceCompose',
#  'RandomChoiceContrast',
#  'RandomChoiceGamma',
#  'RandomChoiceRotate',
#  'RandomChoiceSaturation',
#  'RandomChoiceShear',
#  'RandomChoiceTranslate',
#  'RandomChoiceZoom',
#  'RandomContrast',
#  'RandomCrop',
#  'RandomFlip',
#  'RandomGamma',
#  'RandomGrayscale',
#  'RandomOrder',
#  'RandomRotate',
#  'RandomSaturation',
#  'RandomShear',
#  'RandomTranslate',
#  'RandomZoom',
#  'RangeNormalize',
#  'Rotate',
#  'Saturation',
#  'Shear',
#  'Slice2D',
#  'SpecialCrop',
#  'StdNormalize',
#  'ToCuda',
#  'ToFile',
#  'ToTensor',
#  'ToVariable',
#  'Translate',
#  'Transpose',
#  'TypeCast',
#  'Unsqueeze',
#  'Variable',
#  'Zoom',
# ...
